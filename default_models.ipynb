# %%
class BToModels:

# %% [markdown]
# Возможна ситуация, когда B не  находится в нашем списке
# Тогда

# %%
models = {
    "resnet_abs__relu__no_last_activation":
}

# %%
resnet_abs__relu__no_last_activation["creation"]["encoder_creator"]()
resnet_abs__relu__no_last_activation["creation"]["decoder_creator"]()
resnet_abs__relu__no_last_activation["weights"]["B6"]["encoder_weights"]

# %%
import torch.nn as nn
from torchvision.models import resnet18

from models import create_resnet_encoder

resnet_abs__relu__no_last_activation = {
    "creation": {
        "encoder_creator": lambda: create_resnet_encoder(
            resnet18(), nn.Identity(), nn.Sigmoid()), 
        "decoder_creator": lambda: create_resnet_encoder(
            resnet18(), nn.Identity(), nn.Sigmoid())
    },
    "weights": {
        "B6": {
            "encoder_weights": None,
            "decoder_weights": None
        }
    }
}

# %%
b_to_models[6][B6ModelNames.RESNET_ABS_RELU_NO_LAST_ACTIVATION]
# Out:
# {'encoder_creator': None,
#  'encoder_weights': None,
#  'decoder_creator': None,
#  'decoder_weights': None}
